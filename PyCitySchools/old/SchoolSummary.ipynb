# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
lstschools=school_data_complete['school_name'].unique()
totschools =len(lstschools)

# %%
totstudents = school_data_complete['student_name'].count()

# %% [markdown]
# ## School Summary
#
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
dftop = school_data_complete[['school_name','type','Student ID','budget','math_score','reading_score']]

# %%
gpdftop= dftop.groupby(['school_name','type','budget'])

# %%
studcnt=gpdftop['Student ID'].count()

# %%
perstud=gpdftop['budget'].max()/studcnt

# %%
avgmathsc=gpdftop['math_score'].mean()
avgreadsc=gpdftop['reading_score'].mean()

# %%
mathover70 = gpdftop.apply(lambda x: x.math_score > 70).sum()
readover70 = gpdftop.apply(lambda x: x.reading_score > 70).sum()

# %%
totmathcnt = gpdftop['math_score'].count()
totreadcnt = gpdftop['reading_score'].count()

# %%
pctmath =(mathover70 / totmathcnt)*100
pctread =(readover70 / totreadcnt)*100

# %%
overallpassrate=(pctmath + pctread)/2

# %%
dfstudfinal = pd.DataFrame({
    'Total Number of Students':studcnt,
    'Per Student Budget':perstud,
    'Average Math Score':avgmathsc,
    'Average Reading Score':avgreadsc,
    'Overall Passing Rate':overallpassrate,
    'Percent Who Passed Math':pctmath,
    'Percent Who Passed Reading':pctread})

# %%
dfstudfinal
# Out:
#                                         Total Number of Students  \
# school_name           type     budget
# Bailey High School    District 3124928                      4976
# Cabrera High School   Charter  1081356                      1858
# Figueroa High School  District 1884411                      2949
# Ford High School      District 1763916                      2739
# Griffin High School   Charter  917500                       1468
# Hernandez High School District 3022020                      4635
# Holden High School    Charter  248087                        427
# Huang High School     District 1910635                      2917
# Johnson High School   District 3094650                      4761
# Pena High School      Charter  585858                        962
# Rodriguez High School District 2547363                      3999
# Shelton High School   Charter  1056600                      1761
# Thomas High School    Charter  1043130                      1635
# Wilson High School    Charter  1319574                      2283
# Wright High School    Charter  1049400                      1800
#
#                                         Per Student Budget  \
# school_name           type     budget
# Bailey High School    District 3124928               628.0
# Cabrera High School   Charter  1081356               582.0
# Figueroa High School  District 1884411               639.0
# Ford High School      District 1763916               644.0
# Griffin High School   Charter  917500                625.0
# Hernandez High School District 3022020               652.0
# Holden High School    Charter  248087                581.0
# Huang High School     District 1910635               655.0
# Johnson High School   District 3094650               650.0
# Pena High School      Charter  585858                609.0
# Rodriguez High School District 2547363               637.0
# Shelton High School   Charter  1056600               600.0
# Thomas High School    Charter  1043130               638.0
# Wilson High School    Charter  1319574               578.0
# Wright High School    Charter  1049400               583.0
#
#                                         Average Math Score  \
# school_name           type     budget
# Bailey High School    District 3124928           77.048432
# Cabrera High School   Charter  1081356           83.061895
# Figueroa High School  District 1884411           76.711767
# Ford High School      District 1763916           77.102592
# Griffin High School   Charter  917500            83.351499
# Hernandez High School District 3022020           77.289752
# Holden High School    Charter  248087            83.803279
# Huang High School     District 1910635           76.629414
# Johnson High School   District 3094650           77.072464
# Pena High School      Charter  585858            83.839917
# Rodriguez High School District 2547363           76.842711
# Shelton High School   Charter  1056600           83.359455
# Thomas High School    Charter  1043130           83.418349
